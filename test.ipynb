# %%
import requests
import cv2
import base64
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread(r'C:\Users\Xiaomi\Pictures\8.jpg', cv2.IMREAD_COLOR)
plt.imshow(image)

# %%
_, data = cv2.imencode('.jpg', image)

# %%
r = requests.post('http://127.0.0.1:5000/api/add_links', json={'image': base64.b64encode(data).decode('utf-8')})

# %%
r.json()
# Out:
# {'message': 'Add connected persons.| Find 6 links.'}

# %%
image_data = base64.decodebytes(faces[0].encode('utf-8'))
nparr = np.fromstring(image_data, np.uint8)
img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
r = requests.post('http://127.0.0.1:5000/api/add_face', json={'face': faces[2], 'id': '2252748124', 'meta': "'id': '2252748124'"})

# %%
r.json()
# Out:
# {'message': 'Success'}

# %%
r = requests.post('http://127.0.0.1:5000/api/search', json={'face': faces[0], 'k': 3})

# %%
image_data = base64.decodebytes(r.json()['result'][0]['face'].encode('utf-8'))
nparr = np.fromstring(image_data, np.uint8)
img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
r.json()['result'][0]['score']
# Out:
# 5.960464477539063e-08

# %%
r = requests.post('http://127.0.0.1:5000/api/link', json={'id': r.json()['result'][0]['id']})

# %%
image_data = base64.decodebytes(r.json()['result'][2]['face'].encode('utf-8'))
nparr = np.fromstring(image_data, np.uint8)
img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# C:\Users\Xiaomi\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead

# %%
len(r.json()['result'])
# Out:
# 165
